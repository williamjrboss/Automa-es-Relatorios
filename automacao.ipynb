# %%
# !pip install yfinance pyautogui
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pyautogui
import pyperclip 
import pandas as pd

# %%
acao =  input("Qual codigo da ação desejada: ")
petrobras = yf.Ticker(acao).history('6mo')
fechamento = petrobras.Close
fechamento.plot()
# Out:
# c:\Users\will-\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# <Axes: xlabel='Date'>

# %%
# maáximo
maximo = fechamento.max() 

# minimo

minimo  = fechamento.min()

# cotação atual

atual = fechamento[-1]
# Out:
# C:\Users\will-\AppData\Local\Temp\ipykernel_1216\638970572.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   atual = fechamento[-1]

# %%
pyautogui.PAUSE = 3
pyautogui.hotkey("win")
pyautogui.click(x=770, y=164)
pyperclip.copy("chrome")
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('enter')

pyperclip.copy("gmail.com")
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('enter')

pyautogui.click(x=150, y=239)
pyperclip.copy("testtest@gmail.com")
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('tab') 
pyperclip.copy('relatorio')
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('tab') 
pyperclip.copy("Conteudo ou anexo")
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=1214, y=972)

# %%
import time

time.sleep(5)

pyautogui.position()
# Out:
# Point(x=1203, y=971)
